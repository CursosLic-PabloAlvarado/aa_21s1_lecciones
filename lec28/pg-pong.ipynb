# %% [markdown]
# # Policy Gradient - Pong
#
# Trains an agent with (stochastic) Policy Gradients on Pong. Uses OpenAI Gym.
#
# Author: Andrej Karpathy
# Git: https://gist.github.com/karpathy/a4166c7fe253700972fcbc77e4ea32c5
#
# This needs the Atari environments:

# %%
#!pip install gym 
#!pip install 'gym[box2d]'
#!pip install atari_py

# %% [markdown]
# You will also need to install the Atari ROM once: https://github.com/openai/atari-py#roms

# %%
import numpy as np
import pickle as pickle
import gym

from IPython.display import clear_output

# %% [markdown]
# ## Hyperparameters

# %%
H = 200 # number of hidden layer neurons
batch_size = 10 # every how many episodes to do a param update?
learning_rate = 1e-4
gamma = 0.99 # discount factor for reward
decay_rate = 0.99 # decay factor for RMSProp leaky sum of grad^2

render_every = 100

resume = True # resume from previous checkpoint?
render = True

# %% [markdown]
# ## Model initialization

# %%
# model initialization
D = 80 * 80 # input dimensionality: 80x80 grid
if resume:
  model = pickle.load(open('save.p', 'rb'))
else:
  model = {}
  model['W1'] = np.random.randn(H,D) / np.sqrt(D) # "Xavier" initialization
  model['W2'] = np.random.randn(H) / np.sqrt(H)

grad_buffer = { k : np.zeros_like(v) for k,v in model.items() } # update buffers that add up gradients over a batch
rmsprop_cache = { k : np.zeros_like(v) for k,v in model.items() } # rmsprop memory

# %%
def sigmoid(x): 
  return 1.0 / (1.0 + np.exp(-x)) # sigmoid "squashing" function to interval [0,1]

# %%
def prepro(I):
  """ prepro 210x160x3 uint8 frame into 6400 (80x80) 1D float vector """
  I = I[35:195] # crop
  I = I[::2,::2,0] # downsample by factor of 2
  I[I == 144] = 0 # erase background (background type 1)
  I[I == 109] = 0 # erase background (background type 2)
  I[I != 0] = 1 # everything else (paddles, ball) just set to 1
  return I.astype(np.float).ravel()

# %%
def discount_rewards(r):
  """ take 1D float array of rewards and compute discounted reward """
  discounted_r = np.zeros_like(r)
  running_add = 0
  for t in reversed(range(0, r.size)):
    if r[t] != 0: running_add = 0 # reset the sum, since this was a game boundary (pong specific!)
    running_add = running_add * gamma + r[t]
    discounted_r[t] = running_add
  return discounted_r

# %%
def policy_forward(x):
  h = np.dot(model['W1'], x)
  h[h<0] = 0 # ReLU nonlinearity
  logp = np.dot(model['W2'], h)
  p = sigmoid(logp)
  return p, h # return probability of taking action 2, and hidden state

# %%
def policy_backward(eph, epdlogp):
  """ backward pass. (eph is array of intermediate hidden states) """
  dW2 = np.dot(eph.T, epdlogp).ravel()
  dh = np.outer(epdlogp, model['W2'])
  dh[eph <= 0] = 0 # backpro prelu
  dW1 = np.dot(dh.T, epx)
  return {'W1':dW1, 'W2':dW2}

# %%
env = gym.make("Pong-v0")
observation = env.reset()
prev_x = None # used in computing the difference frame
xs,hs,dlogps,drs = [],[],[],[]
running_reward = None
reward_sum = 0
episode_number = 0

# %%
while True:
  if render and episode_number % render_every == 0: env.render()

  # preprocess the observation, set input to network to be difference image
  cur_x = prepro(observation)
  x = cur_x - prev_x if prev_x is not None else np.zeros(D)
  prev_x = cur_x

  # forward the policy network and sample an action from the returned probability
  aprob, h = policy_forward(x)
  action = 2 if np.random.uniform() < aprob else 3 # roll the dice!

  # record various intermediates (needed later for backprop)
  xs.append(x) # observation
  hs.append(h) # hidden state
  y = 1 if action == 2 else 0 # a "fake label"
  dlogps.append(y - aprob) # grad that encourages the action that was taken to be taken (see http://cs231n.github.io/neural-networks-2/#losses if confused)

  # step the environment and get new measurements
  observation, reward, done, info = env.step(action)
  reward_sum += reward

  drs.append(reward) # record reward (has to be done after we call step() to get reward for previous action)

  if done: # an episode finished
    episode_number += 1

    # stack together all inputs, hidden states, action gradients, and rewards for this episode
    epx = np.vstack(xs)
    eph = np.vstack(hs)
    epdlogp = np.vstack(dlogps)
    epr = np.vstack(drs)
    xs,hs,dlogps,drs = [],[],[],[] # reset array memory

    # compute the discounted reward backwards through time
    discounted_epr = discount_rewards(epr)
    # standardize the rewards to be unit normal (helps control the gradient estimator variance)
    discounted_epr -= np.mean(discounted_epr)
    discounted_epr /= np.std(discounted_epr)

    epdlogp *= discounted_epr # modulate the gradient with advantage (PG magic happens right here.)
    grad = policy_backward(eph, epdlogp)
    for k in model: grad_buffer[k] += grad[k] # accumulate grad over batch

    # perform rmsprop parameter update every batch_size episodes
    if episode_number % batch_size == 0:
      for k,v in model.items():
        g = grad_buffer[k] # gradient
        rmsprop_cache[k] = decay_rate * rmsprop_cache[k] + (1 - decay_rate) * g**2
        model[k] += learning_rate * g / (np.sqrt(rmsprop_cache[k]) + 1e-5)
        grad_buffer[k] = np.zeros_like(v) # reset batch gradient buffer

    # boring book-keeping
    running_reward = reward_sum if running_reward is None else running_reward * 0.99 + reward_sum * 0.01
    print('\nresetting env. episode reward total was %f. running mean: %f' % (reward_sum, running_reward))
    if episode_number % 100 == 0:
        pickle.dump(model, open('save.p', 'wb'))
        clear_output(wait=True)
        
    reward_sum = 0
    observation = env.reset() # reset env
    prev_x = None

  if reward != 0: # Pong has either +1 or -1 reward exactly when game ends.
    print(('ep %d: game finished, reward: %f        ' % (episode_number, reward)) + ('' if reward == -1 else '\n'),end='\r')
# Out:
# ep 100: game finished, reward: 1.000000         !!!!!!!!
# ep 100: game finished, reward: 1.000000         !!!!!!!!
# ep 100: game finished, reward: -1.000000
# resetting env. episode reward total was -19.000000. running mean: -19.485256
# ep 101: game finished, reward: 1.000000         !!!!!!!!
#
# resetting env. episode reward total was -20.000000. running mean: -19.490403
# ep 102: game finished, reward: 1.000000         !!!!!!!!
# ep 102: game finished, reward: 1.000000         !!!!!!!!
# ep 102: game finished, reward: 1.000000         !!!!!!!!
# ep 102: game finished, reward: -1.000000
# resetting env. episode reward total was -18.000000. running mean: -19.475499
# ep 103: game finished, reward: -1.000000
# resetting env. episode reward total was -21.000000. running mean: -19.490744
# ep 104: game finished, reward: -1.000000
# resetting env. episode reward total was -21.000000. running mean: -19.505837
# ep 105: game finished, reward: 1.000000         !!!!!!!!
# ep 105: game finished, reward: -1.000000
# resetting env. episode reward total was -20.000000. running mean: -19.510779
# ep 106: game finished, reward: 1.000000         !!!!!!!!
# ep 106: game finished, reward: -1.000000
# resetting env. episode reward total was -20.000000. running mean: -19.515671
# ep 107: game finished, reward: 1.000000         !!!!!!!!
# ep 107: game finished, reward: 1.000000         !!!!!!!!
# ep 107: game finished, reward: -1.000000
# resetting env. episode reward total was -19.000000. running mean: -19.510514
# ep 108: game finished, reward: 1.000000         !!!!!!!!
# ep 108: game finished, reward: 1.000000         !!!!!!!!
# ep 108: game finished, reward: 1.000000         !!!!!!!!
# ep 108: game finished, reward: 1.000000         !!!!!!!!
#
# resetting env. episode reward total was -17.000000. running mean: -19.485409
# ep 109: game finished, reward: 1.000000         !!!!!!!!
# ep 109: game finished, reward: 1.000000         !!!!!!!!
# ep 109: game finished, reward: -1.000000
# resetting env. episode reward total was -19.000000. running mean: -19.480555
# ep 110: game finished, reward: 1.000000         !!!!!!!!
# ep 110: game finished, reward: 1.000000         !!!!!!!!
# ep 110: game finished, reward: 1.000000         !!!!!!!!
# ep 110: game finished, reward: -1.000000
# resetting env. episode reward total was -18.000000. running mean: -19.465749
# ep 111: game finished, reward: 1.000000         !!!!!!!!
# ep 111: game finished, reward: 1.000000         !!!!!!!!
# ep 111: game finished, reward: 1.000000         !!!!!!!!
# ep 111: game finished, reward: 1.000000         !!!!!!!!
# ep 111: game finished, reward: 1.000000         !!!!!!!!
# ep 111: game finished, reward: -1.000000
# resetting env. episode reward total was -16.000000. running mean: -19.431092
# ep 112: game finished, reward: -1.000000
# resetting env. episode reward total was -21.000000. running mean: -19.446781
# ep 113: game finished, reward: 1.000000         !!!!!!!!
# ep 113: game finished, reward: -1.000000
# resetting env. episode reward total was -20.000000. running mean: -19.452313
# ep 114: game finished, reward: 1.000000         !!!!!!!!
# ep 114: game finished, reward: 1.000000         !!!!!!!!
# ep 114: game finished, reward: -1.000000
# resetting env. episode reward total was -19.000000. running mean: -19.447790
# ep 115: game finished, reward: 1.000000         !!!!!!!!
# ep 115: game finished, reward: 1.000000         !!!!!!!!
#
# resetting env. episode reward total was -19.000000. running mean: -19.443312
# ep 116: game finished, reward: 1.000000         !!!!!!!!
# ep 116: game finished, reward: 1.000000         !!!!!!!!
# ep 116: game finished, reward: -1.000000
# resetting env. episode reward total was -19.000000. running mean: -19.438879
# ep 117: game finished, reward: 1.000000         !!!!!!!!
# ep 117: game finished, reward: 1.000000         !!!!!!!!
# ep 117: game finished, reward: -1.000000
# resetting env. episode reward total was -19.000000. running mean: -19.434490
# ep 118: game finished, reward: 1.000000         !!!!!!!!
# ep 118: game finished, reward: 1.000000         !!!!!!!!
# ep 118: game finished, reward: 1.000000         !!!!!!!!
#
# resetting env. episode reward total was -18.000000. running mean: -19.420145
# ep 119: game finished, reward: 1.000000         !!!!!!!!
# ep 119: game finished, reward: -1.000000
# resetting env. episode reward total was -20.000000. running mean: -19.425944
# ep 120: game finished, reward: 1.000000         !!!!!!!!
# ep 120: game finished, reward: 1.000000         !!!!!!!!
# ep 120: game finished, reward: -1.000000
# resetting env. episode reward total was -19.000000. running mean: -19.421684
# ep 121: game finished, reward: -1.000000
# resetting env. episode reward total was -21.000000. running mean: -19.437467
# ep 122: game finished, reward: 1.000000         !!!!!!!!
# ep 122: game finished, reward: 1.000000         !!!!!!!!
#
# resetting env. episode reward total was -19.000000. running mean: -19.433093
# ep 123: game finished, reward: 1.000000         !!!!!!!!
# ep 123: game finished, reward: -1.000000
# resetting env. episode reward total was -20.000000. running mean: -19.438762
# ep 124: game finished, reward: 1.000000         !!!!!!!!
# ep 124: game finished, reward: 1.000000         !!!!!!!!
# ep 124: game finished, reward: -1.000000
# resetting env. episode reward total was -19.000000. running mean: -19.434374
# ep 125: game finished, reward: -1.000000
# resetting env. episode reward total was -21.000000. running mean: -19.450031
# ep 126: game finished, reward: 1.000000         !!!!!!!!
# ep 126: game finished, reward: 1.000000         !!!!!!!!
# ep 126: game finished, reward: 1.000000         !!!!!!!!
# ep 126: game finished, reward: 1.000000         !!!!!!!!
# ep 126: game finished, reward: -1.000000
# resetting env. episode reward total was -17.000000. running mean: -19.425530
# ep 127: game finished, reward: 1.000000         !!!!!!!!
# ep 127: game finished, reward: -1.000000
# resetting env. episode reward total was -20.000000. running mean: -19.431275
# ep 128: game finished, reward: 1.000000         !!!!!!!!
# ep 128: game finished, reward: 1.000000         !!!!!!!!
# ep 128: game finished, reward: 1.000000         !!!!!!!!
# ep 128: game finished, reward: 1.000000         !!!!!!!!
# ep 128: game finished, reward: -1.000000
# resetting env. episode reward total was -17.000000. running mean: -19.406962
# ep 129: game finished, reward: 1.000000         !!!!!!!!
# ep 129: game finished, reward: -1.000000
# resetting env. episode reward total was -20.000000. running mean: -19.412893
# ep 130: game finished, reward: 1.000000         !!!!!!!!
# ep 130: game finished, reward: 1.000000         !!!!!!!!
# ep 130: game finished, reward: -1.000000
# resetting env. episode reward total was -19.000000. running mean: -19.408764
# ep 131: game finished, reward: 1.000000         !!!!!!!!
# ep 131: game finished, reward: -1.000000
# resetting env. episode reward total was -20.000000. running mean: -19.414676
# ep 132: game finished, reward: 1.000000         !!!!!!!!
# ep 132: game finished, reward: 1.000000         !!!!!!!!
#
# resetting env. episode reward total was -19.000000. running mean: -19.410529
# ep 133: game finished, reward: -1.000000
# resetting env. episode reward total was -21.000000. running mean: -19.426424
# ep 134: game finished, reward: 1.000000         !!!!!!!!
# ep 134: game finished, reward: -1.000000
# resetting env. episode reward total was -20.000000. running mean: -19.432160
# ep 135: game finished, reward: 1.000000         !!!!!!!!
# ep 135: game finished, reward: 1.000000         !!!!!!!!
# ep 135: game finished, reward: -1.000000
# resetting env. episode reward total was -19.000000. running mean: -19.427838
# ep 136: game finished, reward: -1.000000
# resetting env. episode reward total was -21.000000. running mean: -19.443560
# ep 137: game finished, reward: 1.000000         !!!!!!!!
# ep 137: game finished, reward: -1.000000
# resetting env. episode reward total was -20.000000. running mean: -19.449124
# ep 138: game finished, reward: -1.000000
# resetting env. episode reward total was -21.000000. running mean: -19.464633
# ep 139: game finished, reward: 1.000000         !!!!!!!!
# ep 139: game finished, reward: 1.000000         !!!!!!!!
# ep 139: game finished, reward: 1.000000         !!!!!!!!
# ep 139: game finished, reward: 1.000000         !!!!!!!!
# ep 139: game finished, reward: -1.000000
# resetting env. episode reward total was -17.000000. running mean: -19.439987
# ep 140: game finished, reward: -1.000000
# resetting env. episode reward total was -21.000000. running mean: -19.455587
# ep 141: game finished, reward: 1.000000         !!!!!!!!
# ep 141: game finished, reward: 1.000000         !!!!!!!!
# ep 141: game finished, reward: -1.000000
# resetting env. episode reward total was -19.000000. running mean: -19.451031
# ep 142: game finished, reward: 1.000000         !!!!!!!!
# ep 142: game finished, reward: 1.000000         !!!!!!!!
# ep 142: game finished, reward: -1.000000
# resetting env. episode reward total was -19.000000. running mean: -19.446521
# ep 143: game finished, reward: 1.000000         !!!!!!!!
# ep 143: game finished, reward: 1.000000         !!!!!!!!
# ep 143: game finished, reward: 1.000000         !!!!!!!!
#
# resetting env. episode reward total was -18.000000. running mean: -19.432055
# ep 144: game finished, reward: 1.000000         !!!!!!!!
# ep 144: game finished, reward: 1.000000         !!!!!!!!
# ep 144: game finished, reward: 1.000000         !!!!!!!!
# ep 144: game finished, reward: 1.000000         !!!!!!!!
# ep 144: game finished, reward: 1.000000         !!!!!!!!
# ep 144: game finished, reward: 1.000000         !!!!!!!!
# ep 144: game finished, reward: -1.000000
# resetting env. episode reward total was -15.000000. running mean: -19.387735
# ep 145: game finished, reward: -1.000000
# resetting env. episode reward total was -21.000000. running mean: -19.403857
# ep 146: game finished, reward: 1.000000         !!!!!!!!
# ep 146: game finished, reward: 1.000000         !!!!!!!!
# ep 146: game finished, reward: 1.000000         !!!!!!!!
# ep 146: game finished, reward: 1.000000         !!!!!!!!
# ep 146: game finished, reward: -1.000000
# resetting env. episode reward total was -17.000000. running mean: -19.379819
# ep 147: game finished, reward: 1.000000         !!!!!!!!
# ep 147: game finished, reward: 1.000000         !!!!!!!!
# ep 147: game finished, reward: 1.000000         !!!!!!!!
# ep 147: game finished, reward: -1.000000
# resetting env. episode reward total was -18.000000. running mean: -19.366021
# ep 148: game finished, reward: 1.000000         !!!!!!!!
# ep 148: game finished, reward: 1.000000         !!!!!!!!
# ep 148: game finished, reward: -1.000000
# resetting env. episode reward total was -19.000000. running mean: -19.362360
# ep 149: game finished, reward: 1.000000         !!!!!!!!
# ep 149: game finished, reward: 1.000000         !!!!!!!!
# ep 149: game finished, reward: 1.000000         !!!!!!!!
# ep 149: game finished, reward: -1.000000
# resetting env. episode reward total was -18.000000. running mean: -19.348737
# ep 150: game finished, reward: 1.000000         !!!!!!!!
# ep 150: game finished, reward: 1.000000         !!!!!!!!
# ep 150: game finished, reward: -1.000000
# resetting env. episode reward total was -19.000000. running mean: -19.345249
# ep 151: game finished, reward: 1.000000         !!!!!!!!
# ep 151: game finished, reward: -1.000000
# resetting env. episode reward total was -20.000000. running mean: -19.351797
# ep 152: game finished, reward: -1.000000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_14694/3872803866.py in <module>
#      18
#      19   # step the environment and get new measurements
# ---> 20   observation, reward, done, info = env.step(action)
#      21   reward_sum += reward
#      22
#
# ~/anaconda3/envs/aa/lib/python3.9/site-packages/gym/wrappers/time_limit.py in step(self, action)
#      16             self._elapsed_steps is not None
#      17         ), "Cannot call env.step() before calling reset()"
# ---> 18         observation, reward, done, info = self.env.step(action)
#      19         self._elapsed_steps += 1
#      20         if self._elapsed_steps >= self._max_episode_steps:
#
# ~/anaconda3/envs/aa/lib/python3.9/site-packages/gym/envs/atari/atari_env.py in step(self, a)
#     132             num_steps = self.np_random.randint(self.frameskip[0], self.frameskip[1])
#     133         for _ in range(num_steps):
# --> 134             reward += self.ale.act(action)
#     135         ob = self._get_obs()
#     136
#
# ~/anaconda3/envs/aa/lib/python3.9/site-packages/atari_py/ale_python_interface.py in act(self, action)
#     150
#     151     def act(self, action):
# --> 152         return ale_lib.act(self.obj, int(action))
#     153
#     154     def game_over(self):
#
# KeyboardInterrupt:
